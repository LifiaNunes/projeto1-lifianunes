# %% [markdown]
# <a href="https://colab.research.google.com/github/LifiaNunes/projeto1-lifianunes/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
# !pip install polars

# %%
# !pip install matplotlib

# %%
# !pip install chardet

# %%
# @title Texto de título padrão
import pandas as pd
import chardet
import numpy as np
import polars as pl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dados_enem_2021_BA.csv')

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210051128744    2021                4       F                1
# 1  210054173438    2021                5       F                1
# 2  210052118573    2021                3       F                1
# 3  210052350230    2021               10       F                1
# 4  210053156861    2021                9       M                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                2                0          2
# 1            2                 1                2                0          2
# 2            3                 1                2                0          2
# 3            2                 1                1                8          1
# 4            2                 1                1                5          1
#
#    ...                                 TX_GABARITO_CH  \
# ...

# %%
df.tail()
# Out:
#        NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 57029  210054165358    2021                9       M                1
# 57030  210052538146    2021                3       F                1
# 57031  210051931823    2021                4       M                1
# 57032  210051664288    2021                3       F                1
# 57033  210052993165    2021               11       F                1
#
#        TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 57029            1                 1                1                6
# 57030            3                 1                1                0
# 57031            2                 1                3                0
# 57032            3                 1                2                0
# 57033            3                 1                1                9
#
#        TP_ESCOLA  ...                                 TX_GABARITO_CH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57034 entries, 0 to 57033
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            57034 non-null  int64
#  1   NU_ANO                  57034 non-null  int64
#  2   TP_FAIXA_ETARIA         57034 non-null  int64
#  3   TP_SEXO                 57034 non-null  object
#  4   TP_ESTADO_CIVIL         57034 non-null  int64
#  5   TP_COR_RACA             57034 non-null  int64
#  6   TP_NACIONALIDADE        57034 non-null  int64
#  7   TP_ST_CONCLUSAO         57034 non-null  int64
#  8   TP_ANO_CONCLUIU         57034 non-null  int64
#  9   TP_ESCOLA               57034 non-null  int64
#  10  TP_ENSINO               23751 non-null  float64
#  11  IN_TREINEIRO            57034 non-null  int64
#  12  CO_MUNICIPIO_ESC        11380 non-null  float64
#  13  NO_MUNICIPIO_ESC        11380 non-null  object
# ...

# %%
df.shape
# Out:
# (57034, 51)

# %%
df.describe().transpose()
# Out:
#                           count          mean            std           min  \
# NU_INSCRICAO            57034.0  2.100527e+11  982303.093237  2.100510e+11
# NU_ANO                  57034.0  2.021000e+03       0.000000  2.021000e+03
# TP_FAIXA_ETARIA         57034.0  4.646895e+00       3.190155  1.000000e+00
# TP_ESTADO_CIVIL         57034.0  1.019497e+00       0.333736  0.000000e+00
# TP_COR_RACA             57034.0  2.320861e+00       0.899196  0.000000e+00
# TP_NACIONALIDADE        57034.0  1.033068e+00       0.197100  0.000000e+00
# TP_ST_CONCLUSAO         57034.0  1.692850e+00       0.693977  1.000000e+00
# TP_ANO_CONCLUIU         57034.0  1.727899e+00       3.383226  0.000000e+00
# TP_ESCOLA               57034.0  1.484571e+00       0.589788  1.000000e+00
# TP_ENSINO               23751.0  1.012884e+00       0.112775  1.000000e+00
# IN_TREINEIRO            57034.0  1.229267e-01       0.328356  0.000000e+00
# ...

# %%
df.nunique().sort_values(ascending= True)
# Out:
# NU_ANO                        1
# SG_UF_PROVA                   1
# CO_UF_PROVA                   1
# TP_LINGUA                     2
# TP_SEXO                       2
# TP_LOCALIZACAO_ESC            2
# IN_TREINEIRO                  2
# TP_ENSINO                     2
# TP_PRESENCA_MT                3
# TP_PRESENCA_CH                3
# TP_PRESENCA_CN                3
# TP_PRESENCA_LC                3
# TP_ESCOLA                     3
# TP_SIT_FUNC_ESC               4
# TP_ST_CONCLUSAO               4
# TP_DEPENDENCIA_ADM_ESC        4
# TP_NACIONALIDADE              5
# TP_ESTADO_CIVIL               5
# TP_COR_RACA                   6
# TX_GABARITO_CH                8
# TX_GABARITO_MT                8
# TP_STATUS_REDACAO             8
# TX_GABARITO_CN                9
# NU_NOTA_COMP2                10
# TX_GABARITO_LC               10
# NU_NOTA_COMP4                11
# NU_NOTA_COMP3                11
# NU_NOTA_COMP1                11
# NU_NOTA_COMP5                11
# ...

# %%
df.query('TP_ESCOLA == 2').NU_NOTA_MT.mean()
# Out:
# 489.19594586745654

# %%
df.query("TP_ESCOLA == 3").NU_NOTA_MT.mean()
# Out:
# 586.6091814159292

# %%
df.TP_SEXO.value_counts().plot(kind= 'bar')
# Out:
# <Axes: >

# %%
df.TP_ESCOLA.value_counts().plot(kind = 'bar')
plt.title('tipo de escola participantes Enem')
# Out:
# Text(0.5, 1.0, 'tipo de escola participantes Enem')

# %%
df_counts = df.CO_MUNICIPIO_PROVA.value_counts().reset_index()
df_counts = df_counts.rename(columns={'index': 'Municipio', 'CO_MUNICIPIO_PROVA': 'QUANTIDADE'})
